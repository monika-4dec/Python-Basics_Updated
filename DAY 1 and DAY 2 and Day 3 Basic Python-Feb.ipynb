# %% [markdown]
# ### Day 1
# - 1. [Using Interpreter](#section1)</br>
#     - 1.1 [ Python's Interactive Prompt](#section101)<br/>
#     - 1.2 [ Scripting](#section102)<br/>
#     - 1.3 [Program Execution Model](#section103)<br/>
#     - 1.4 [Program Architecture: modules](#section104)<br/>
#     - 1.5 [How to run Python program](#section105)<br/>
#     - 1.6 [Quick Intro Anaconda & Jupiter Notebook(IDLES)](#section106)<br/>

# %% [markdown]
# <a id=sectio></f>
# ## What is python and why it is so popular ?

# %% [markdown]
# Python is one among the most popular dynamic programming languages that is being used today. Python is an open-source and object-oriented programming language developed by Dutchman Guido van Possum in 1980s. This language can be utilized for a wide range of applications like scripting, developing and testing.  Due to its elegance and simplicity, top technology organizations like Dropbox, Google, Quora, Mozilla, Hewlett-Packard, Qualcomm, IBM, and Cisco have implemented Python.
#
#
# ![image.png](attachment:image.png)
#
# Several websites state that Python is one among the most famous programming language of 2016. Because of its implementation and syntax, it pressures more on code readability. When compared to other programming languages like C++ and Java, it requires the programmer to develop lesser codes. It offers automatic memory management and several standard libraries for the programmer. Once a programmer completes Python certification training, he can gain knowledge and experience in a wide range of top IT organizations. It is a general-purpose and high-level coding language.
#
# Because of its features, a large number of programmers across the world, showing interest in making use of this language to develop websites, GUI applications, and mobile applications. The main reason that brings Python one among the top coding languages is that it allows the developers to figure out the concepts by developing readable and less code. Several advantages of Python supports the programmers to alleviate the effort as well as the time required for developing complex and large applications.

# %% [markdown]
# <a id=section1></f>
# ## 1. Using the Interpreter
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Interpreter** : An interpreter is a program that reads and executes code. This includes source code, pre-compiled code, and scripts. So if we talk about python interpreter it will execute the code in pytyhon by taking single code line at a time.
#
# **Scripting** : Any program written in python is called a script.The interpreter reads and executes each line of code one at a time, just like a SCRIPT for a play or an audition, hence the the term "scripting language". Python uses an interpreter to translate and run its code and that's why it's called a **scripting language**
#
# **Kernel** : An operating system or OS is system software that works as an interface between hardware components and end-user. It enables other programs to run.
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# ### Python Program Executing Model & Architecture
#
# A Python program is constructed from code blocks. A block is a piece of Python program text that is executed as a unit. The following are blocks: a module, a function body, and a class definition. Each command typed interactively is a block. A script file (a file given as standard input to the interpreter or specified as a command line argument to the interpreter) is a code block. A script command (a command specified on the interpreter command line with the -c option) is a code block. The string argument passed to the built-in functions eval() and exec() is a code block.
#
# A code block is executed in an execution frame. A frame contains some administrative information (used for debugging) and determines where and how execution continues after the code block’s execution has completed.
#
# ![image.png](attachment:image.png)
#
# - A scope defines the visibility of a name within a block. If a local variable is defined in a block, its scope includes that block. If the definition occurs in a function block, the scope extends to any blocks contained within the defining one, unless a contained block introduces a different binding for the name.
#
# ## Run a Python Program

# %% [raw]
# # a=10
# #Shift Enter

# %% [markdown]
# # I am using python

# %% [markdown]
# I am using Python

# %% [raw]
# I am using Python

# %%
#a=15

b=13

# %%
#inbuild function
#user defined function


print(b)

# %%
h=15
print(h)
#name(): inbuild function
#userfunction(): user -defined function
# Out:
# 15

# %%
a='gkd6983468346gka'
b="hkjha"

# %%
t=9
x="python"
y='monika'
z=14.5 #float

print(t)
print(y)
print(x)
print(z)
t
x,y,t



#x y and z can be in any order
# Out:
# 9
# monika
# python
# 14.5
# ('python', 'monika', 9)

# %%
w=x+y #concatenating strings

print(x+y)


print(x+" "+y)

print(y,t,x,z)
# Out:
# pythonmonika
# python monika
# monika 9 python 14.5

# %%
print(w)
# Out:
# pythonmonika

# %%
a="2"
b=3
#c=a+" "+b
c=a+b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_5968\2426459400.py in <module>
#       2 b=3
#       3 #c=a+" "+b
# ----> 4 c=a+b
#       5 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#type(a,b,c)
#unlike print function
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_5968\303203518.py in <module>
# ----> 1 type(a,b,c)
#
# TypeError: type.__new__() argument 2 must be tuple, not int

# %%
type(a)
print(type(a))
print(type(b))
#print(type(c))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#c=7
print(type(a))
print(type(b))
c=a+b # concatenating a and b
print(type(c))

# %% [markdown]
# ## Installation
#
# The following link provides the complete installation guide for python basic IDLE
#
# https://www.python.org/downloads/

# %% [markdown]
# ## Anaconda & Jupyter notebook
#
# Anaconda is a free and open-source distribution of the Python and R programming languages for scientific computing (data science, machine learning applications, large-scale data processing, predictive analytics, etc.), that aims to simplify package management and deployment. Package versions are managed by the package management system conda.The Anaconda distribution is used by over **13 million** users and includes more than **1400** popular **data-science** packages suitable for Windows, Linux, and MacOS.
#
# ![image.png](attachment:image.png)
#
# The following link will guide you to anaconda interface and download details:
# https://www.anaconda.com/

# %% [markdown]
# ### Day 1
# - 2. [. Python Scripting (2hrs)](#section2)</br>
#     - 1.1 [ Introduction](#section201)<br/>
#     - 1.2 [Sequence types & Assignments](#section106)<br/>
#     - 1.3 [List Iteration](#section106)<br/>
#     - 1.4 [Mutable Vs Immutable Objects](#section106)<br/>
#     - 1.5 [Membership Statements](#section106)<br/>
#     - 1.6 [Multi Target Assignment](#section106)<br/>

# %%
# The Python Variable Function
x=9
y="monika"
z=12.50
print(y,z,x) #Shortcut: Ctrl+/, select all and then Ctrl+/
# Out:
# monika 12.5 9

# %%
#integer:- %d
#string:- %s
#float:- %f

# %%
print("Neha has %d Rupees and %s has 10 Rupees" %(x,y))
# Out:
# Neha has 9 Rupees and monika has 10 Rupees

# %%
## %s-strings,%d-int,%f-decimal or float

print("%s is %d years old and her height = %f inches" %(y,x,z))
# Out:
# monika is 9 years old and her height = 12.500000 inches

# %%
#type function
type(12),type(18.6),type("monika"),type(-13),type(-14.0),type("b"),type("&"),type("67A")
#type(99.5)
# Out:
# (int, float, str, int, float, str, str, str)

# %%
#type function
type(12),type(18.6),type("monika"),type(-13),type(-14.0),type("b"),type("&")
type("67A")

# %%
##Type Casting
float(18)
float(20)
# Out:
# 20.0

# %%
print(float(18))
# Out:
# 18.0

# %%
print(int(13.7))

print(str(8.9))

print(int("13"))
int(13.5)
a='19'
# Out:
# 13
# 8.9
# 13

# %%
print(float('halshfl'))
print(float(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_5968\780618863.py in <module>
# ----> 1 print(float('halshfl'))
#       2 print(float(a))
#
# ValueError: could not convert string to float: 'halshfl'

# %%
int("12") #string converted into integer
str(12) #integer into a string

int(12.98) #float into integer
float(12) #integer into float

str(33.3)
    a=3

int(12)

str("12")
str(int(12))

int(str('12'))

# %%
int(str('monika'))

# %%
print("monika")
1_x=5

# %% [markdown]
# ## INDENTATION

# %%
##Variable Decalartion
t=9
x,y,z=1,"a",14.5
a_1= 9
print(a_1)
print(x)
print(y)

# %%
t=9
v=6
y_h=t+v
print(t+v) #arithmetic addition
h='9'
f='6'
print(h+f)#concatenation of strings
w=54
print("c")
#indentation error discussion

# %%
print("mo\n     nika \n           arora")

# %%
a=34
b=36
print("3\n6 \n2\n4")
# Out:
# 3
# 6
# 2
# 4

# %% [markdown]
# ## Input

# %% [markdown]
# # Coding Exercise: the output should be like:-

# %%
#Day 1 - String Manipulation
#String Concatenation is done with the "+" sign.
#e.g. print("Hello " + "world")
#New lines can be created with a backslash and n. -->

# %% [markdown]
# # The Python Input Function and new line

# %%
print("monika")
print("arora")

# %%
print("monika \narora")

# %%
a_1="Varsha"
a_1

# %%
y=input("what is the price of shoes\n")
print(y)
# Out:
# what is the price of shoes
# 5000
# 5000

# %%
type(int(y))
# Out:
# int

# %%
a=input("What is your age?\n")
#input(): inbuild function: always throws a string data type

print(a)

print(type(a))
b=int(a)
type(b)

# %%
a=input("Name")

# %%
type(int(a))

# %%
a="monika"
b="arora"
print(a+" "+b)

# %%
input("Name?\n")

# %%
print("What is your name?")
a=input("What is your name?")
a
b=input("What is your name?\n")

# %%
print("Hello"+" "+ input('What is your name?'))

# %%
## name = str, age = int ,years of exper = float
name=input(" Enter your Name: ")
age=int(input("Age:"))
exp=float(input("Job exp in years:"))
#print("your details are:")
print("your details are: \nName = %d" %(age))
#print("Name = %s" %(name))

# %%
a="21"
b=21
c=21.78
print(len(a))
# a=15
# len(a)

# %% [markdown]
# # The Python len Function

# %%
#object: List:- [1,2.34,"gh"]

# %%
a=[1,"monika",3,4.5,3,'abc']
len(a)
# Out:
# 6

# %%
x="Python is easy langauge"
len(x)
# Out:
# 23

# %%
a="20.67"
len(a)
# Out:
# 5

# %% [markdown]
# # Exercise: Write a program that prints the number of characters in a user's name.

# %%
a=input("What is your name?")
len(a)

# %%
x=input('age')
print(x)
# Out:
# age28
# 28

# %%
b=15794327
len(b)

# %% [markdown]
# # Exercise:
#  If a hold 5 and b holds 6, then it should print a= 6 and b= 5

# %%
a=5
b=6
c=a #third variable c
a=b
b=c
print("a=",a)
print("b=",b)

# %%
a=5
b=6
#multi assignment of variable
a,b=b,a
print(a,b)
# Out:
# 6 5

# %%
a=5
b=6
a,b=b,a
print(a,b)

# %% [markdown]
# # PROJECT

# %%
# "Welcome to the Band Name Generator."
# "What's the name of the city you grew up in?
# Noida
# "What's your pet's name?
# Frosty
# "Your band name could be Noida Frosty

# %%
print("Welcome to the Band Name Generator.")
street = input("What's the name of the city you grew up in?\n")
pet = input("What's your pet's name?\n")
print("Your band name could be " + street + " " + pet)

# %% [markdown]
# ## Built-in Types
# Approximately two dozen types are built into the Python interpreter and grouped into a few major categories, as shown :
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Types

# %%
a=[1,234,3,4,5,"baC6",1.2]
len(a)
# Out:
# 7

# %%
print(len("Hello"))

# %%
#print(len(12345)) # This will give error because we need to understand about data types
# Data Types
# string
print("Hello"[-4:-1]) # Find the last character?
# Out:
# ell

# %%
# a=123

# b="123"

# c=123.23

# d=True

# print(type(a))
# print(type(b))
# print(type(c))
# print(type(d))

# #now print 12345

# %%
len("h73750DLJALDi")

# %% [markdown]
# # Exercise:
# Write a program that adds the digits in a 2 digit number. e.g. if the input was 35, then the output should be 3 + 5 = 8

# %%
number="63"
#number=input("enter a two digit number")
first_digit = int(number[0])

second_digit = int(number[1])

#Add the two digits together
output = first_digit + second_digit

print(output)

# %% [markdown]
# # Mathematical Operators

# %%
x=9
x*x+2*x-6
print(2*3) #2 times 3, 2X3
print(2**3) #2 to the power 3

# %%
#PEMDAS or BODMAS:= (),**,*,/,+,- 
print(3*3+3/3-3) #(9+1-3) ----> (10-3)

print(3*(3+3/3-3))
# Out:
# 7.0
# 3.0

# %%
8/3 # Gives a floating point number
# Out:
# 2.6666666666666665

# %%
print(23/8)
print(round(23/8,0))
print(round(23/8,2))
# Out:
# 2.875
# 3.0
# 2.88

# %%
a=12.99
import math #library
math.ceil(12.3)# 12--------->13
# Out:
# 13

# %%
math.floor(12.3)# 12<---------13
# Out:
# 12

# %%
## Numbers 
# 3+4
# 3-8
# 4*5
# 3**4
# 14/3

# %%
print(13//3)

print(13%3)
# Out:
# 4
# 1

# %% [markdown]
# # Code Challenge
# BMI Calculator: https://app.codingrooms.com/w/26NvYLliNdNo

# %%
height = input("enter your height in ft: ")
weight = input("enter your weight in kg: ")


weight_as_int = int(weight)
height_as_float = float(height)

# Using the exponent operator **
bmi = weight_as_int / height_as_float ** 2
# or using multiplication and PEMDAS
#bmi = weight_as_int / (height_as_float * height_as_float)

bmi_as_int = int(bmi)

print(bmi_as_int)

# %% [markdown]
# ## Conditional
# ## if / else

# %% [raw]
# if condition:
#     do this
# else:
#     do this

# %%
#water_level=50;
water_level=int(input("The water level is"));
if water_level>80:
    #print("Drain water")
    b=50
    c=90
    a=b+c
    print(a)
else:
    print("Continue")
# Out:
# The water level is30
# Continue

# %%
# Roller Coaster ride

print("Welcome to the rollercoster ride")
height=int(input("What is your height in cms?"))

if height>120:
    print("You can ride")
else:
    print("You have to grow taller before you take a ride :)")

# %% [markdown]
# # Comparison Operators
#
# # assigning values : =
# # equality: ==

# %%
# Roller Coaster ride

print("Welcome to the rollercoster ride")
height=int(input("What is your height?"))

if height==120:
    print("You can ride")
else:
    print("You have to grow taller before you take a ride :)")

# %% [raw]
# Instructions
# Write a program that works out whether if a given number is an odd or even number.
#
# (Even numbers can be divided by 2 with no remainder.
#
# e.g. 86 is even because 86 ÷ 2 = 43
#
# 43 does not have any decimal places. Therefore the division is clean.
#
# e.g. 59 is odd because 59 ÷ 2 = 29.5
#
# 29.5 is not a whole number, it has decimal places. Therefore there is a remainder of 0.5, so the division is not clean.
#
# The modulo is written as a percentage sign (%) in Python. It gives you the remainder after a division.)

# %%
a=int(input("Enter a Number"))
if a%2==1: # comparitive operator: ==
    print("Its an ODD Number")
else:
    print("Its an EVEN number")

# %% [raw]
# Nested If statement
#
# if condition:
#     if another condition:
#         do this A
#     else:
#         do this B
# else:
#     do this

# %%
a=int(input("enter the height in cms"))
w=int(input("enter your weight in kgs"))
if a>120:
    if 50<w<70:
        print("The ticket price is Rs 120")
    else:
        print("The ticket price is Rs 200")
else:
    print("You cant buy the ticket")
# Out:
#   File "C:\Users\monika201103\AppData\Local\Temp\1\ipykernel_5968\3926064172.py", line 4
#     if 50<w<70:
#     ^
# IndentationError: expected an indented block

# %% [raw]
# if/elif/else
#
# if condition 1:
#     do A
# elif condition 2:
#     do X
# elif condition 3:
#     do B
# else:
#     do this
#
#
# Example:
# For under 12 years: The price of the ticket should be $12
# For 12 -18 years: The price of the ticket should be $50
# For Over 18 years: The rpice of the ticket should be $100
# But this is applied only to those whose height is more than 120 cms

# %%
a=int(input("enter the height"))
age=int(input("enter your age"))
if a>120 or a==120:
    if age<12 or age==12:
        print("Pay $12")
    elif 12<age<18:
        print("Pay $50")
    elif age>=18:
        print("Pay $100")
else:
    print("Sorry! No rides for now")
# Out:
# enter the height130
# enter your age18
# Pay $100

# %% [markdown]
# ## Sequence type & Assignment
# - Sequences represent ordered sets of objects indexed by nonnegative integers and include strings, Unicode strings, lists, and tuples. -Strings are sequences of characters -
# - lists and tuples are sequences of arbitrary Python objects.
# - Strings and tuples are immutable; lists allow insertion, deletion, and substitution of elements.
# - All sequences support iteration.

# %% [markdown]
# ## Strings

# %%
x1=1234
x2=1234
#print(x1+x2)
x="data"
#print(x+x)
print(len(x))
print(x[-1])
#"as12"-aplha numeric
#"1234"-num
#"abc"-
a="4#%&"
b=" 4#%&"

# %%
print('hello') #single quotes
print("hello") #double quotes
print("hello\nmonika") # next line
print("hello"+"monika")
# add a space in between hello and monika

# %%
c=" "

print(c.isspace())
# Out:
# True

# %%
x="daTa"
print(x.upper())

x="DAta12"
print(x.capitalize())

print(x.casefold()) # same as lower


print(x.isalnum())

print(x.isalpha())

print(x.isascii())

print(x.isdecimal())
print(x.isspace())

# %%
a="Python is a data science tool"
b="1234"
print("This is concading=",a+b)
print("Length of string a =",len(a)) #len() for finding length
print(a.isupper())# checks upper case
print(b.islower())# checks lower case
c=a.upper()
print(c)
print("Converting a into uppercase=",c)
d=b.capitalize()
print(d)

# %% [markdown]
# ## Indexing

# %%
b="ab3jhgksdg3c12334"
print(b)

print(b[0]) # Start

# %%
print(b[-1]) # End

print(b[:-2]) # before mentioned index

print(b[-2:]) # equal & after index
print(b[3:6])
print(b[3:-2])
print(b[3:12])

# %%
print(b.count("3"))
print(b.index("3"))

# %%
b="aba12"
print(b[-1:])
print(b[1:3])
print(b[-2:])
print(b.count("a"))
#b.index("a")
print(b)

# %%
del b
print(b)

# %% [raw]
# Lists are mutable objects
#
# list=[item1,item2]

# %%
X=['12',12,12.0]
print(X)
type(X)
# Out:
# ['12', 12, 12.0]
# list

# %%
##Lists
b=[3,'3',3.0]
l2=[4,"python",12.90]
print(l2)
b

# %%
l=[1,2,3]
l1=[1,'a',"12"]
l=l+l1 #appending to the list
print(l)
# Out:
# [1, 2, 3, 1, 'a', '12']

# %%
l+l1
print(a[1::])
print(l1)
print(len(l1))

# %%
print(len(a))

# %%
l=[1,2,3]

# %%
print(l)
l[2]=9
l[0]
print(l)

# %%
l=[1,2,3,4,5,6,'12']
print(l)
del l[-5]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, '12']
# [1, 2, 4, 5, 6, '12']

# %%
del l[-1]
print(l)

# %%
l

# %%
l=[1,2,3]
print(l)

l.append(10)
print(l)

l.insert(3,100)
print(l)
# Out:
# [1, 2, 3]

# %%
print(l)

print(l*2)
l

a=["c","e"]
print(a)
print(l)
# Out:
# [1, 2, 3, 100, 10]
# [1, 2, 3, 100, 10, 1, 2, 3, 100, 10]
# ['c', 'e']
# [1, 2, 3, 100, 10]

# %%
print(l)
x=sorted(l,reverse= True)
print(x)
# Out:
# [1, 2, 3, 100, 10]
# [100, 10, 3, 2, 1]

# %%
a=list(range(0,10,2)) #start,stop-1,interval 0 to 9
a
# Out:
# [0, 2, 4, 6, 8]

# %%
a=list(range(1,10,-2))
a
# Out:
# []

# %% [raw]
# More on:
#
# https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# ## Mutable vs Immutable Objects

# %% [markdown]
# ## Tuples
#
# Python Tuple is a collection of objects separated by commas. In some ways, a tuple is similar to a list in terms of indexing, nested objects, and repetition but a tuple is immutable, unlike lists which are mutable.

# %%
# Creating a List with
# the use of Numbers
# code to test that tuples are mutable
List = [1, 2, 4, 4, 3, 3, 3, 6, 5]
print("Original list ", List)
 
List[3] = 77
print("Example to show mutability ", List)
# Out:
# Original list  [1, 2, 4, 4, 3, 3, 3, 6, 5]
# Example to show mutability  [1, 2, 4, 77, 3, 3, 3, 6, 5]

# %%
# Tuples are not mutable. Code to test that tuples are immutable
# Tuples are immutable
 
tuple1 = (1, 2, 4, 4, 3, 3, 3, 6, 5)
tuple1[3] = 77
print(tuple1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_5968\254182186.py in <module>
#       3
#       4 tuple1 = (1, 2, 4, 4, 3, 3, 3, 6, 5)
# ----> 5 tuple1[3] = 77
#       6 print(tuple1)
#
# TypeError: 'tuple' object does not support item assignment

# %% [raw]
# As tuples are stored in a single memory block therefore they don’t require extra space for new objects whereas the lists are allocated in two blocks, first the fixed one with all the Python object information and second a variable sized block for the data.

# %%
t=(1,23)
t2=[1,2,"a"]
print(type(t2))
print(type(t))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
import sys
a_list = []
a_tuple = ()
a_list = ["Basics", "of", "Python"]
a_tuple = ("Basics", "of", "Python")
print(sys.getsizeof(a_list))
print(sys.getsizeof(a_tuple))
# Out:
# 120
# 64

# %% [markdown]
# ### Mapping Types objects : Dictionary
# - A mapping object represents an arbitrary collection of objects that are indexed by another collection of nearly arbitrary key values. Unlike a sequence, a mapping object is unordered and can be indexed by numbers, strings, and other objects. Mappings are **mutable**.
#
# -  You can use any immutable object as a dictionary key value (strings, numbers, tuples, and so on). Lists, dictionaries, and tuples containing mutable objects cannot be used as keys (the dictionary type requires key values to remain constant).

# %%
# keys: values
d={}
print(d)
# Out:
# {}

# %%
d=[100,'monika,12.50']
d1={"monika":23.21,102:"arora"}
print(type(d))
type(d1)
# Out:
# <class 'list'>
# dict

# %%
example={'k':55,'value':55,'k':56}
print(example)
# Out:
# {'k': 56, 'value': 55}

# %%
#Can we repeat key values in dic : if we repeat key it would overwrite
d={100:"monika",102:"arora",'monika':"arora1"}
d
# Out:
# {100: 'monika', 102: 'arora', 'monika': 'arora1'}

# %%
print("Type= " ,type(d))
# Out:
# Type=  <class 'dict'>

# %%
print(d.keys(),d.values())
# Out:
# dict_keys(['monika', 102]) dict_values([23.21, 'arora'])

# %%
print(d)
d[103]="viru"
print(d)
# Out:
# {'monika': 23.21, 102: 'arora'}
# {'monika': 23.21, 102: 'arora', 103: 'viru'}

# %%
print(d)
del d[102]
print(d)
# Out:
# {'monika': 23.21, 102: 'arora'}
# {'monika': 23.21}

# %%
d

# %% [markdown]
# # Merge two Python dictionaries into one
#
# dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
# dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
#
# Expected output:
#
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %%
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirtyy': 30, 'Fourty': 40, 'Fifty': 50}

dict3 = {**dict2, **dict1}
print(dict3)
# Out:
# {'Thirtyy': 30, 'Fourty': 40, 'Fifty': 50, 'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# ## Set Types Objects
# A set is an unordered collection of unique items. Unlike sequences, sets provide no indexing or slicing operations. They are also unlike dictionaries in that there are no key values associated with the objects. In addition, the items placed into a set must be **immutable**.
# - Two different set types are available: set is a mutable set, and frozenset is an immutable set.

# %%
s={}
s={11,11,44,0,1,22,89}
s
# Out:
# {0, 1, 11, 22, 44, 89}

# %%
s = set({1,12,30,4,8,8,9,0}) # set assignment
print(s)
# Out:
# {0, 1, 4, 8, 9, 12, 30}

# %%
print("set=",s)
print("Type=",type(s))

# %%
s.add(19)# mutuable operation
s
# Out:
# {0, 1, 4, 8, 9, 12, 19, 30}

# %%
s={1,2,3,4,5,6}
t={3,4,6}

# %%
print(s.issubset(s))
#t.issubset(s)
# Out:
# True

# %% [markdown]
# ### Methods & Operations for all set types
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Methods & Operations for mutuable set types¶
# ![image.png](attachment:image.png)

# %%
#converting a list into a set

num1=[1,2,3]

print(type(num1))

num=set(num1)

#num = set([1, 2, 3])

type(num)
# Out:
# <class 'list'>
# set

# %%
num.add(4)
num

# %% [raw]
# Sets:- are implemented in such a way that they don’t allow mutable objects, however, Python sets in themselves are mutable in nature.
#
# Frozensets:- are just like sets but they can’t be changed. That is, frozensets are the immutable version of Python sets.

# %%
num=set([1,2,3])
print(num)
# Out:
# {1, 2, 3}

# %%
num = frozenset([1, 2, 3])
print(num)
# Out:
# frozenset({1, 2, 3})

# %%
num=({1,2,3})
type(num)

num=frozenset([34,6,0])
type(num)
# Out:
# frozenset

# %%
num.add(4) #shows its immutability
#num
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_24888\1710609164.py in <module>
# ----> 1 num.add(4) #shows its immutability
#       2 #num
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ### List Methods
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Membership Statements
# - Membership operators are operators used to validate the membership of a value. It test for membership in a sequence, such as strings, lists, or tuples.

# %%
a="aapple is good for health"
b="aple is g"
b in a 
print((b in a),(b==a)) # compares menbers
print(b==a)
#b is a # exact equal
#b is not a
# Out:
# False False
# False

# %% [markdown]
# ## Multi Target Assignment

# %%
a , b = 1,2
print("a=",a )
print("b=",b)

# %%
a=1
b=13
c=14
d=9
c,d=14,9

# %%
c , s = 26.2 ,"monika"

print("%s age = %f"%(s,c))

# %%
a=3
b=4
a,b = b,a # swapping
a

# %%
b

# %% [markdown]
# ### String Methods & Functions
# ![image.png](attachment:image.png)

# %% [raw]
# ##1. Create a List of length =7
# Type cast it [strings,tuples,sets and dict)
#
# 2. Write script to check whether an input string is:
#     1. Ok (lenghth is b/w: 2-6) , invalid
#     2. Ok (alphanumeric) , invalid
#     3. end
#
#  3. create a dict with names as name and age as values.

# %%
#4. Find the size of a tuple
import sys
 
# sample Tuples
Tuple1 = ("A", 1, "B", 2, "C", 3)
Tuple2 = ("Geek1", "Raju", "Geek2", "Nikhil", "Geek3", "Deepanshu")
Tuple3 = ((1, "Lion"), ( 2, "Tiger"), (3, "Fox"), (4, "Wolf"))
 
# print the sizes of sample Tuples
print("Size of Tuple1: " + str(sys.getsizeof(Tuple1)) + "bytes")
print("Size of Tuple2: " + str(sys.getsizeof(Tuple2)) + "bytes")
print("Size of Tuple3: " + str(sys.getsizeof(Tuple3)) + "bytes")

# %%
# 5. Write a program to make a simple calculator
# This function adds two numbers
def add(x, y):
    return x + y

# This function subtracts two numbers
def subtract(x, y):
    return x - y

# This function multiplies two numbers
def multiply(x, y):
    return x * y

# This function divides two numbers
def divide(x, y):
    return x / y


print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    # take input from the user
    choice = input("Enter choice(1/2/3/4): ")

    # check if choice is one of the four options
    if choice in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))
        
        # check if user wants another calculation
        # break the while loop if answer is no
        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "no":
          break
    else:
        print("Invalid Input")
